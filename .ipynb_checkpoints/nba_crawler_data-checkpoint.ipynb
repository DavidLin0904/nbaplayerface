# %%
def update_insert(headers, games, updateset=True):
    for i in range(len(headers)):
        for j in range(len(games)):
            if len(games) != 0: # 出賽場數
                myplayer = {headers[i]:games[j][i]}
                updateplayer = {"$set": {headers[i]:games[j][i]}}
                collection.update_one(myplayer, updateplayer, True)

# %%
# 刪除資料庫
from pymongo import MongoClient
conn = MongoClient("mongodb://localhost")
conn.drop_database(conn.NBAPlayerData)

# %%
# import
from pymongo import MongoClient
from bson.objectid import ObjectId
from nba_api.stats.static import players
from nba_api.stats.endpoints import playergamelog
import time
# connection
conn = MongoClient("mongodb://localhost")
db = conn.NBAPlayerData
collection = db.playerData
playerid = [str(player["id"]) for player in players.get_active_players()]
for ids in playerid:
    playergamelogs = playergamelog.PlayerGameLog(ids).get_dict()['resultSets'][0]
    headers = playergamelogs['headers']
    data = playergamelogs['rowSet']
    games = [game for game in data]
    update_insert(headers, games)
        
cursor = collection.find()
data = [d for d in cursor] 
print(data)
# Out:
# [{'_id': ObjectId('6267f9d5752d232476464359'), 'SEASON_ID': '22021'}, {'_id': ObjectId('6267f9d5752d2324764643a3'), 'Player_ID': 1630173}, {'_id': ObjectId('6267f9d5752d2324764643ed'), 'Game_ID': '0022101226'}, {'_id': ObjectId('6267f9d5752d2324764643ef'), 'Game_ID': '0022101206'}, {'_id': ObjectId('6267f9d5752d2324764643f1'), 'Game_ID': '0022101197'}, {'_id': ObjectId('6267f9d5752d2324764643f3'), 'Game_ID': '0022101182'}, {'_id': ObjectId('6267f9d5752d2324764643f5'), 'Game_ID': '0022101172'}, {'_id': ObjectId('6267f9d5752d2324764643f7'), 'Game_ID': '0022101151'}, {'_id': ObjectId('6267f9d5752d2324764643f9'), 'Game_ID': '0022101141'}, {'_id': ObjectId('6267f9d5752d2324764643fb'), 'Game_ID': '0022101127'}, {'_id': ObjectId('6267f9d5752d2324764643fd'), 'Game_ID': '0022101109'}, {'_id': ObjectId('6267f9d5752d2324764643ff'), 'Game_ID': '0022101095'}, {'_id': ObjectId('6267f9d5752d232476464401'), 'Game_ID': '0022101076'}, {'_id': ObjectId('6267f9d5752d232476464403'), 'Game_ID': '0022101069'}, {'_id': ObjectId('6267f9d5752d232476464405'), 'Game_ID': '0022101051'}, {'_id': ObjectId('6267f9d5752d232476464407'), 'Game_ID': '0022101044'}, {'_id': ObjectId('6267f9d5752d232476464409'), 'Game_ID': '0022101028'}, {'_id': ObjectId('6267f9d5752d23247646440b'), 'Game_ID': '0022101009'}, {'_id': ObjectId('6267f9d5752d23247646440d'), 'Game_ID': '0022101003'}, {'_id': ObjectId('6267f9d5752d23247646440f'), 'Game_ID': '0022100989'}, {'_id': ObjectId('6267f9d5752d232476464411'), 'Game_ID': '0022100962'}, {'_id': ObjectId('6267f9d5752d232476464413'), 'Game_ID': '0022100458'}, {'_id': ObjectId('6267f9d5752d232476464415'), 'Game_ID': '0022100942'}, {'_id': ObjectId('6267f9d5752d232476464417'), 'Game_ID': '0022100928'}, {'_id': ObjectId('6267f9d5752d232476464419'), 'Game_ID': '0022100726'}, {'_id': ObjectId('6267f9d5752d23247646441b'), 'Game_ID': '0022100906'}, {'_id': ObjectId('6267f9d5752d23247646441d'), 'Game_ID': '0022100896'}, {'_id': ObjectId('6267f9d5752d23247646441f'), 'Game_ID': '0022100880'}, {'_id': ObjectId('6267f9d5752d232476464421'), 'Game_ID': '0022100863'}, {'_id': ObjectId('6267f9d5752d232476464423'), 'Game_ID': '0022100850'}, {'_id': ObjectId('6267f9d5752d232476464425'), 'Game_ID': '0022100834'}, {'_id': ObjectId('6267f9d5752d232476464427'), 'Game_ID': '0022100827'}, {'_id': ObjectId('6267f9d5752d232476464429'), 'Game_ID': '0022100810'}, {'_id': ObjectId('6267f9d5752d23247646442b'), 'Game_ID': '0022100790'}, {'_id': ObjectId('6267f9d5752d23247646442d'), 'Game_ID': '0022100430'}, {'_id': ObjectId('6267f9d5752d23247646442f'), 'Game_ID': '0022100784'}, {'_id': ObjectId('6267f9d5752d232476464431'), 'Game_ID': '0022100767'}, {'_id': ObjectId('6267f9d5752d232476464433'), 'Game_ID': '0022100748'}, {'_id': ObjectId('6267f9d5752d232476464435'), 'Game_ID': '0022100472'}, {'_id': ObjectId('6267f9d5752d232476464437'), 'Game_ID': '0022100715'}, {'_id': ObjectId('6267f9d5752d232476464439'), 'Game_ID': '0022100702'}, {'_id': ObjectId('6267f9d5752d23247646443b'), 'Game_ID': '0022100689'}, {'_id': ObjectId('6267f9d5752d23247646443d'), 'Game_ID': '0022100675'}, {'_id': ObjectId('6267f9d5752d23247646443f'), 'Game_ID': '0022100662'}, {'_id': ObjectId('6267f9d5752d232476464441'), 'Game_ID': '0022100641'}, {'_id': ObjectId('6267f9d5752d232476464443'), 'Game_ID': '0022100633'}, {'_id': ObjectId('6267f9d5752d232476464445'), 'Game_ID': '0022100613'}, {'_id': ObjectId('6267f9d5752d232476464447'), 'Game_ID': '0022100599'}, {'_id': ObjectId('6267f9d5752d232476464449'), 'Game_ID': '0022100584'}, {'_id': ObjectId('6267f9d5752d23247646444b'), 'Game_ID': '0022100573'}, {'_id': ObjectId('6267f9d5752d23247646444d'), 'Game_ID': '0022100563'}, {'_id': ObjectId('6267f9d5752d23247646444f'), 'Game_ID': '0022100545'}, {'_id': ObjectId('6267f9d5752d232476464451'), 'Game_ID': '0022100534'}, {'_id': ObjectId('6267f9d5752d232476464453'), 'Game_ID': '0022100443'}, {'_id': ObjectId('6267f9d5752d232476464455'), 'Game_ID': '0022100351'}, {'_id': ObjectId('6267f9d5752d232476464457'), ...
