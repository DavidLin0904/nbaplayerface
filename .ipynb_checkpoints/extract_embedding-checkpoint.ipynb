# %%
from imutils import paths
import numpy as np
import imutils
import pickle
import cv2
import os

# %%
print("[INFO] loading face detector...")
protoPath = os.path.sep.join(["face_detection_model", "deploy.prototxt"])
# Out:
# [INFO] loading face detector...

# %%
modelPath = os.path.sep.join(["face_detection_model", 
                              "res10_300x300_ssd_iter_140000.caffemodel"])

# %%
detector = cv2.dnn.readNetFromCaffe(protoPath, modelPath)

# %%
print("[INFO] loading face recognizer...")
embedder = cv2.dnn.readNetFromTorch("openface_nn4.small2.v1.t7")
# Out:
# [INFO] loading face recognizer...

# %%
print("[INFO] quantifying faces...")
imagePaths = list(paths.list_images("images"))
# Out:
# [INFO] quantifying faces...

# %%
knownEmbeddings = []
knownNames = []
total = 0

for (i, imagePath) in enumerate(imagePaths):
    print("[INFO] processing image {}/{}".format(i + 1,
          len(imagePaths)))
    name = imagePath.split(os.path.sep)[-2]
    image = cv2.imread(imagePath)
    image = imutils.resize(image, width=600)
    (h, w) = image.shape[:2]
    imageBlob = cv2.dnn.blobFromImage(
        cv2.resize(image, (300, 300)), 1.0, (300, 300),
        (104.0, 177.0, 123.0), swapRB=False, crop=False)
    detector.setInput(imageBlob)
    detections = detector.forward()
    if len(detections) > 0:
        i = np.argmax(detections[0, 0, :, 2])
        confidence = detections[0, 0, i, 2]
        if confidence > 0.5:
            box = detections[0, 0, i, 3:7] * np.array([w, h, w, h])
            (startX, startY, endX, endY) = box.astype("int")
            face = image[startY:endY, startX:endX]
            (fH, fW) = face.shape[:2]
            if fW < 20 or fH < 20:
                continue
            faceBlob = cv2.dnn.blobFromImage(face, 1.0 / 255,
                (96, 96), (0, 0, 0), swapRB=True, crop=False)
            embedder.setInput(faceBlob)
            vec = embedder.forward()
            knownNames.append(name)
            knownEmbeddings.append(vec.flatten())
            total += 1

print("[INFO] serializing {} encodings...".format(total))
data = {"embeddings": knownEmbeddings, "names": knownNames}
f = open("output/embeddings.pickle", "wb")
f.write(pickle.dumps(data))
f.close()
# Out:
# [INFO] processing image 1/207
# [INFO] processing image 2/207
# [INFO] processing image 3/207
# [INFO] processing image 4/207
# [INFO] processing image 5/207
# [INFO] processing image 6/207
# [INFO] processing image 7/207
# [INFO] processing image 8/207
# [INFO] processing image 9/207
# [INFO] processing image 10/207
# [INFO] processing image 11/207
# [INFO] processing image 12/207
# [INFO] processing image 13/207
# [INFO] processing image 14/207
# [INFO] processing image 15/207
# [INFO] processing image 16/207
# [INFO] processing image 17/207
# [INFO] processing image 18/207
# [INFO] processing image 19/207
# [INFO] processing image 20/207
# [INFO] processing image 21/207
# [INFO] processing image 22/207
# [INFO] processing image 23/207
# [INFO] processing image 24/207
# [INFO] processing image 25/207
# [INFO] processing image 26/207
# [INFO] processing image 27/207
# [INFO] processing image 28/207
# [INFO] processing image 29/207
# [INFO] processing image 30/207
# [INFO] processing image 31/207
# [INFO] processing image 32/207
# [INFO] processing image 33/207
# [INFO] processing image 34/207
# [INFO] processing image 35/207
# [INFO] processing image 36/207
# [INFO] processing image 37/207
# [INFO] processing image 38/207
# [INFO] processing image 39/207
# [INFO] processing image 40/207
# [INFO] processing image 41/207
# [INFO] processing image 42/207
# [INFO] processing image 43/207
# [INFO] processing image 44/207
# [INFO] processing image 45/207
# [INFO] processing image 46/207
# [INFO] processing image 47/207
# [INFO] processing image 48/207
# [INFO] processing image 49/207
# [INFO] processing image 50/207
# [INFO] processing image 51/207
# [INFO] processing image 52/207
# [INFO] processing image 53/207
# [INFO] processing image 54/207
# [INFO] processing image 55/207
# [INFO] processing image 56/207
# [INFO] processing image 57/207
# [INFO] processing image 58/207
# [INFO] processing image 59/207
# [INFO] processing image 60/207
# [INFO] processing image 61/207
# [INFO] processing image 62/207
# [INFO] processing image 63/207
# [INFO] processing image 64/207
# [INFO] processing image 65/207
# [INFO] processing image 66/207
# [INFO] processing image 67/207
# [INFO] processing image 68/207
# [INFO] processing image 69/207
# [INFO] processing image 70/207
# [INFO] processing image 71/207
# [INFO] processing image 72/207
# [INFO] processing image 73/207
# [INFO] processing image 74/207
# [INFO] processing image 75/207
# [INFO] processing image 76/207
# [INFO] processing image 77/207
# [INFO] processing image 78/207
# [INFO] processing image 79/207
# [INFO] processing image 80/207
# [INFO] processing image 81/207
# [INFO] processing image 82/207
# [INFO] processing image 83/207
# [INFO] processing image 84/207
# [INFO] processing image 85/207
# [INFO] processing image 86/207
# [INFO] processing image 87/207
# [INFO] processing image 88/207
# [INFO] processing image 89/207
# [INFO] processing image 90/207
# [INFO] processing image 91/207
# [INFO] processing image 92/207
# [INFO] processing image 93/207
# [INFO] processing image 94/207
# [INFO] processing image 95/207
# [INFO] processing image 96/207
# [INFO] processing image 97/207
# [INFO] processing image 98/207
# [INFO] processing image 99/207
# [INFO] processing image 100/207
# [INFO] processing image 101/207
# [INFO] processing image 102/207
# [INFO] processing image 103/207
# [INFO] processing image 104/207
# [INFO] processing image 105/207
# [INFO] processing image 106/207
# [INFO] processing image 107/207
# [INFO] processing image 108/207
# [INFO] processing image 109/207
# [INFO] processing image 110/207
# [INFO] processing image 111/207
# [INFO] processing image 112/207
# [INFO] processing image 113/207
# [INFO] processing image 114/207
# [INFO] processing image 115/207
# [INFO] processing image 116/207
# [INFO] processing image 117/207
# [INFO] processing image 118/207
# [INFO] processing image 119/207
# [INFO] processing image 120/207
# [INFO] processing image 121/207
# [INFO] processing image 122/207
# [INFO] processing image 123/207
# [INFO] processing image 124/207
# [INFO] processing image 125/207
# [INFO] processing image 126/207
# [INFO] processing image 127/207
# [INFO] processing image 128/207
# [INFO] processing image 129/207
# [INFO] processing image 130/207
# [INFO] processing image 131/207
# [INFO] processing image 132/207
# [INFO] processing image 133/207
# [INFO] processing image 134/207
# [INFO] processing image 135/207
# [INFO] processing image 136/207
# [INFO] processing image 137/207
# [INFO] processing image 138/207
# [INFO] processing image 139/207
# [INFO] processing image 140/207
# [INFO] processing image 141/207
# [INFO] processing image 142/207
# [INFO] processing image 143/207
# [INFO] processing image 144/207
# [INFO] processing image 145/207
# [INFO] processing image 146/207
# [INFO] processing image 147/207
# [INFO] processing image 148/207
# [INFO] processing image 149/207
# [INFO] processing image 150/207
# [INFO] processing image 151/207
# [INFO] processing image 152/207
# [INFO] processing image 153/207
# [INFO] processing image 154/207
# [INFO] processing image 155/207
# [INFO] processing image 156/207
# [INFO] processing image 157/207
# [INFO] processing image 158/207
# [INFO] processing image 159/207
# [INFO] processing image 160/207
# [INFO] processing image 161/207
# [INFO] processing image 162/207
# [INFO] processing image 163/207
# [INFO] processing image 164/207
# [INFO] processing image 165/207
# [INFO] processing image 166/207
# [INFO] processing image 167/207
# [INFO] processing image 168/207
# [INFO] processing image 169/207
# [INFO] processing image 170/207
# [INFO] processing image 171/207
# [INFO] processing image 172/207
# [INFO] processing image 173/207
# [INFO] processing image 174/207
# [INFO] processing image 175/207
# [INFO] processing image 176/207
# [INFO] processing image 177/207
# [INFO] processing image 178/207
# [INFO] processing image 179/207
# [INFO] processing image 180/207
# [INFO] processing image 181/207
# [INFO] processing image 182/207
# [INFO] processing image 183/207
# [INFO] processing image 184/207
# [INFO] processing image 185/207
# [INFO] processing image 186/207
# [INFO] processing image 187/207
# [INFO] processing image 188/207
# [INFO] processing image 189/207
# [INFO] processing image 190/207
# [INFO] processing image 191/207
# [INFO] processing image 192/207
# [INFO] processing image 193/207
# [INFO] processing image 194/207
# [INFO] processing image 195/207
# [INFO] processing image 196/207
# [INFO] processing image 197/207
# [INFO] processing image 198/207
# [INFO] processing image 199/207
# [INFO] processing image 200/207
# [INFO] processing image 201/207
# [INFO] processing image 202/207
# [INFO] processing image 203/207
# [INFO] processing image 204/207
# [INFO] processing image 205/207
# [INFO] processing image 206/207
# [INFO] processing image 207/207
# [INFO] serializing 207 encodings...
